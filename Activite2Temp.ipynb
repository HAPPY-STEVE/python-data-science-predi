# %%
import numpy as np 
import csv 
import pandas as pd
from matplotlib import pyplot as plt

def importData():
    df = pd.read_csv("7janvier.csv")
    df=df.dropna()
    jourCherche = df.Consommation
    print("Contents :", jourCherche)
 
#donnes renvoyees vide
#    df = pd.read_csv('eCO2mix_RTE_En-cours-TR_2.csv')
#    df=df.dropna()
#    data = df.Consommation
#    print("Contents :", df)

    df = pd.read_csv('RTE.csv')
    df=df.dropna()
    data2020 = df.Consommation
    print("Contents :", data2020)
    


def defineCorrelation(a1, a2):
    cor = np.corrcoef(a1,a2)
    maxcor = max(cor)

    
def mainProgram():
    pass

importData()
# Out:
# Contents : 0     52379.0
# 2     50669.0
# 4     49032.0
# 6     48827.0
# 8     48573.0
# 10    48075.0
# 12    46518.0
# 14    45499.0
# 16    44486.0
# 18    44080.0
# 20    43929.0
# 22    44453.0
# 24    45159.0
# 26    46028.0
# 28    47097.0
# 30    48255.0
# 32    49531.0
# 34    50450.0
# 36    51301.0
# 38    52537.0
# 40    52834.0
# 42    52994.0
# 44    53503.0
# 46    53974.0
# 48    54543.0
# 50    54560.0
# 52    53853.0
# 54    52265.0
# 56    51872.0
# 58    51440.0
# 60    51513.0
# 62    50616.0
# 64    49993.0
# 66    49441.0
# 68    49959.0
# 70    51614.0
# 72    53273.0
# 74    54342.0
# 76    55403.0
# 78    55150.0
# 80    53852.0
# 82    52410.0
# 84    51229.0
# 86    50141.0
# 88    49545.0
# 90    50205.0
# 92    51686.0
# 94    51365.0
# Name: Consommation, dtype: float64
# Contents : 0        67068.0
# 2        66103.0
# 4        63943.0
# 6        63904.0
# 8        63408.0
#           ...
# 35126    64423.0
# 35128    63505.0
# 35130    64331.0
# 35132    66853.0
# 35134    66750.0
# Name: Consommation, Length: 17568, dtype: float64
